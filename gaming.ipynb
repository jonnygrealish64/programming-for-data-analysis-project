# %%
# importing Python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# the inline command allows use of matplotlib in Jupyter
# %matplotlib inline

# %%
data = pd.read_csv('data/videogames.csv')
data.head()
# Out:
#                            Game   Price    Paid Savings Compatibility  \
# 0                           NaN     NaN     NaN     NaN           NaN
# 1            Astro's Playroom ✔   €0.00   €0.00   €0.00           NaN
# 2  AWAY: The Survival Series 🥳🎁  €29.99   €0.00  €29.99           NaN
# 3                      Beat Cop  €14.99   €1.49  €13.50           NaN
# 4                     Bugsnax ✔  €21.99  €16.49   €5.50           NaN
#
#    Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0         NaN        NaN         NaN         NaN         NaN          NaN
# 1         NaN        NaN         NaN         NaN         NaN          NaN
# 2         NaN        NaN         NaN         NaN         NaN          NaN
# 3         NaN        NaN         NaN         NaN         NaN          NaN
# 4         NaN        NaN         NaN         NaN         NaN          NaN
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
